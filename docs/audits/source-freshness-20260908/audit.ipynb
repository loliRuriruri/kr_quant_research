# %% [markdown]
# # Source freshness audit
# Read-only audit companion. Run from repository root; `probe=False` avoids network. Output describes stored ticker presence, not latest filing completeness.

# %%
from scripts.audit_source_freshness import audit
result = audit(probe=False)
result['freshness'], result['financial_latest_period_counts'], result['official_flow_latest_by_ticker']
